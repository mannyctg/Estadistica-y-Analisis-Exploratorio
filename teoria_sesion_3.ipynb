# %% [markdown]
# # Pruebas de hipotesis
#
# * La Ha plantea que el parametro es mayor que un valor especifico --------- Prueba unilateral derecha o cola superior ( Ha: u > u0 ) -- ppf(1 - alfa)
#
# * La Ha plantea que el parametro es menor que un valor especifico --------- Prueba unilateral izquierda o cola inferior ( Ha: u < u0 ) -- ppf(alfa)
#
# * La Ha plantea que el parametro es diferente ---------- Prueba bilateral ( Ha: u != uo ) -- ppf(alpha/2) y ppf(1 - alpha/2)

# %% [markdown]
# ### Media poblacional (U)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Diferencia de medias
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Proporcion (P)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Cociente de varianzas
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Diferencia de proporciones
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Pruebas de bondad de ajuste
#
# Es un procedimiento especial para determinar si un
# conjunto de datos proviene de una distribucion determinada.
#
# ### Chi cuadrado
